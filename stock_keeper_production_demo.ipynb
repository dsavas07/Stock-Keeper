# %% [markdown]
# # Stock Keeper Production Demo
# Use this notebook to run the production-ready Stock Keeper pipeline on a sample market set.

# %%
import os
from stock_keeper.interface.agent import InteractivePortfolioAgent
from dotenv import load_dotenv, find_dotenv
import matplotlib.pyplot as plt
load_dotenv(find_dotenv())
print('Ready')
# Out:
# Ready

# %%
api_key = os.getenv('FINNHUB_API_KEY')
if not api_key:
    raise ValueError('Set FINNHUB_API_KEY in environment variables before running this notebook.')
agent = InteractivePortfolioAgent(api_key)
question = 'Recommend a moderate-risk long-term one-month portfolio for AAPL MSFT NVDA and INTC.'
result = agent.answer_question(question, symbols=['AAPL','MSFT','NVDA','INTC'], risk_appetite='medium', horizon=90, sector_constraints={'Technology': 0.5})
result
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       4 agent = InteractivePortfolioAgent(api_key)
#       5 question = 'Recommend a moderate-risk long-term one-month portfolio for AAPL MSFT NVDA and INTC.'
# ----> 6 result = agent.answer_question(question, symbols=['AAPL','MSFT','NVDA','INTC'], risk_appetite='medium', horizon=90, sector_constraints={'Technology': 0.5})
#       7 result
#
# File c:\Users\Dsavs\Documents\Python_Scripts\Stock-Keeper\stock_keeper\interface\agent.py:29, in InteractivePortfolioAgent.answer_question(self, question, symbols, horizon, risk_appetite, sector_constraints)
#      26 risk = risk_appetite or parsed.get("risk_appetite", "medium")
#      28 agent = PortfolioAgent(api_key=self.api_key, cache_path=self.cache_path)
# ---> 29 return agent.recommend(
#      30     symbols=selected_symbols,
#      31     horizon=horizon,
#      32     risk_appetite=risk,
#      33     sector_constraints=sector_constraints,
#      34 )
#
# File c:\Users\Dsavs\Documents\Python_Scripts\Stock-Keeper\stock_keeper\pipeline.py:73, in PortfolioAgent.recommend(self, symbols, horizon, risk_appetite, weights, max_allocation, min_allocation, top_n, sector_constraints)
#      71 sector_map = {}
#      72 for symbol in symbols:
# ---> 73     df = self._get_price_df(symbol)
#      74     if df.empty:
#      75         continue
#
# File c:\Users\Dsavs\Documents\Python_Scripts\Stock-Keeper\stock_keeper\pipeline.py:22, in PortfolioAgent._get_price_df(self, symbol)
#      20 to_ts = int(datetime.datetime.utcnow().timestamp())
#      21 from_ts = int((datetime.datetime.utcnow() - datetime.timedelta(days=self.window_days)).timestamp())
# ---> 22 data = self.client.get_historical_prices(symbol, from_ts=from_ts, to_ts=to_ts)
#      23 if data.get("s") != "ok":
#      24     raise ValueError(f"No price data for {symbol}")
#
# File c:\Users\Dsavs\Documents\Python_Scripts\Stock-Keeper\stock_keeper\clients\finnhub_client.py:66, in FinnhubClient.get_historical_prices(self, symbol, from_ts, to_ts, resolution)
#      65 def get_historical_prices(self, symbol: str, from_ts: int, to_ts: int, resolution: str = "D") -> Dict:
# ---> 66     return self._get("stock/candle", {"symbol": symbol, "from": from_ts, "to": to_ts, "resolution": resolution})
#
# File c:\Users\Dsavs\Documents\Python_Scripts\Stock-Keeper\stock_keeper\clients\finnhub_client.py:58, in FinnhubClient._get(self, path, params)
#      56 url = f"{self.BASE_URL}/{path}"
#      57 resp = requests.get(url, params=params, timeout=15)
# ---> 58 resp.raise_for_status()
#      59 data = resp.json()
#      61 cache[key] = data
#
# File c:\Users\Dsavs\Documents\Python_Scripts\Stock-Keeper\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://finnhub.io/api/v1/stock/candle?symbol=AAPL&from=1742354880&to=1773890880&resolution=D&token=d64fgfpr01qkcggre4qgd64fgfpr01qkcggre4r0

# %%
alloc = result.get('allocation', {})
symbols = list(alloc.keys())
weights = list(alloc.values())
plt.figure(figsize=(7, 5))
plt.pie(weights, labels=symbols, autopct='%1.1f%%')
plt.title('Recommended Portfolio Allocation')
plt.show()
print('Portfolio metrics:', result.get('portfolio_metrics'))
print('Risk notes:', result.get('risk_notes'))
