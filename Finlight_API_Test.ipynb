# %% [markdown]
# ## Finlight POST Fetch Articles

# %%
import os
from finlight_client import FinlightApi, ApiConfig
from finlight_client.models import GetArticlesParams
import pandas as pd
import json
import duckdb
from functools import reduce
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
from datetime import datetime, timedelta

finlight_api_key = os.getenv('FINLIGHT_API_KEY')

# Get the current time
now = datetime.now()

# Subtract 24 hours
twenty_four_hours_ago = now - timedelta(hours=24)

def finlight_get_articles( 
    query = '', 
    sources = ['*'], 
    excludeSources = ['economictimes.indiatimes.com'], 
    countries = ['US'], 
    ## categories: str | None = "markets,economy,business,politics,geopolitics,regulation,technology,energy,commodities,crypto,health,climate,security", 
    from_date = twenty_four_hours_ago.strftime("%Y-%m-%dT%H:%M"), 
    to_date = now.strftime("%Y-%m-%dT%H:%M"),
    language = 'en',
    includeEntities = True,
    excludeEmptyContent = True,
    includeContent = True,
    pageSize = 100, 
    page = 1, 
    orderBy = 'publishDate', order = 'DESC'
) -> pd.DataFrame:
    client = FinlightApi(
        config=ApiConfig(
            api_key=finlight_api_key
        )
    )

    params = GetArticlesParams(query=query, 
    sources=sources, 
    excludeSources=excludeSources, 
    countries=countries, 
    ## categories=categories, 
    from_=from_date, 
    to=to_date, 
    language=language,
    includeEntities=includeEntities,
    excludeEmptyContent=excludeEmptyContent,
    includeContent=includeContent,
    pageSize=pageSize, 
    page=page, 
    orderBy=orderBy, order=order
    ) 
    articles = client.articles.fetch_articles(params=params)

    articles_df = pd.DataFrame([article.model_dump() for article in articles.articles])
    return articles_df

# %% [raw]
# params = GetArticlesParams(query='ticker:AAPL',
#     sources=['*'],
#     excludeSources=['economictimes.indiatimes.com'],
#     countries=['US'],
#     ## categories=categories,
#     from_= twenty_four_hours_ago.strftime("%Y-%m-%dT%H:%M"),
#     to = now.strftime("%Y-%m-%dT%H:%M"),
#     pageSize=1000, page=1, orderBy='publishDate', order='DESC'
#     )
#
# params

# %%
df = finlight_get_articles(query='ticker:AAPL')
df
# Out:
#                                                 link  \
# 0  https://finance.yahoo.com/sectors/technology/a...
# 1  https://www.benzinga.com/markets/tech/26/04/51...
# 2  https://www.businesstoday.in/markets/stocks/st...
# 3  https://www.benzinga.com/news/space/26/04/5161...
# 4  https://finance.yahoo.com/markets/stocks/artic...
# 5  https://www.investing.com/news/stock-market-ne...
# 6  https://www.cnbc.com/2026/04/01/thursdays-big-...
#
#                                                title  \
# 0  Apple looks behind in AI. History says don’t c...
# 1  Gavin Newsom Hails Apple's '50 Years Of Innova...
# 2  50 years of Apple: $44,074! Just $100 investme...
# 3  Globalstar Stock Pops More Than 15% After Repo...
# 4  Globalstar Rallies on Report That Amazon Is in...
# 5  Globalstar shares surge to 18-yr high on repor...
# 6  Thursday's big stock stories: What’s likely to...
#
#                 publishDate                source language  \
# 0 2026-04-02 09:00:00+00:00     finance.yahoo.com       en
# 1 2026-04-02 08:43:48+00:00      www.benzinga.com       en
# 2 2026-04-02 07:51:28+00:00  www.businesstoday.in       en
# 3 2026-04-02 01:58:27+00:00      www.benzinga.com       en
# 4 2026-04-01 23:37:04+00:00     finance.yahoo.com       en
# 5 2026-04-01 23:28:23+00:00     www.investing.com       en
# 6 2026-04-01 23:12:09+00:00          www.cnbc.com       en
#
#                                              summary  \
# 0  Apple’s $150 billion in cash, a massive ecosys...
# 1  Gavin Newsom praised Apple&#39;s 50 years of i...
# 2  Over the last five years, the counter gained 1...
# 3  Amazon in said to be in talks to acquire Globa...
# 4  (Bloomberg) -- Globalstar Inc. shares jumped m...
# 5
# 6  The major averages rose to start the second qu...
#
#                                               images createdAt sentiment  \
# 0  [https://media.zenfs.com/en/quartz_855/c249cdc...      None      None
# 1  [https://www.benzinga.com/files/images/story/2...      None      None
# 2  [https://akm-img-a-in.tosshub.com/businesstoda...      None      None
# 3  [https://www.benzinga.com/files/images/story/2...      None      None
# 4                                                 []      None      None
# 5  [https://i-invdn-com.investing.com/news/LYNXMP...      None      None
# 6  [https://image.cnbcfm.com/api/v1/image/1082776...      None      None
#
#   confidence content companies
# 0       None    None      None
# 1       None    None      None
# 2       None    None      None
# 3       None    None      None
# 4       None    None      None
# 5       None    None      None
# 6       None    None      None
